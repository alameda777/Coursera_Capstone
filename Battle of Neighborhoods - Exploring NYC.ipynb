# %% [markdown]
# # Business Problem

# %% [markdown]
# The estate department of the government of Colombia is looking for the best location for its new consulate to serve Colombian nationals residing in the city of New York. In order to solve this problem, I will explore all the boroughs of NYC to find the areas most populated with Colombian people. I will do this by finding out which borough has the larger number of Colombian restaurants this will give me the right indication where the Colombian population resides within NYC and therefore where is the best location for the new Colombian consulate, which needs to be close to the people that it will serve.

# %% [markdown]
# # Data

# %% [markdown]
# To solve this problem I will use the dataset provided in the lab https://cocl.us/new_york_dataset which has the necessary information to segment the citie's neighborhoods. Also I will use the Fousquare API to explore the venues.

# %%
#!conda install -c conda-forge folium=0.5.0 --yes
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
import requests
import sys
from bs4 import BeautifulSoup
import os
import folium # map rendering library
from geopy.geocoders import Nominatim 
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.colors as colors
# %matplotlib inline


print('Libraries imported.')
# Out:
# Libraries imported.

# %% [markdown]
# Now we define a function to get the geocodes i.e latitude and longitude of a given location using geopy.

# %%
def geo_location(address):
    # get geo location of address
    geolocator = Nominatim(user_agent="ny_explorer")
    location = geolocator.geocode(address)
    latitude = location.latitude
    longitude = location.longitude
    return latitude,longitude

# %% [markdown]
# We query the FourSquare API to get the top 300 venues within a radius of 2000 mts for a given latitude and longitude. The output will be venue id , venue name and category.

# %%
def get_venues(lat,lng):
    
    #set variables
    radius=2000
    LIMIT=300
    CLIENT_ID = 'ABKHZGTMF5MNAOGB0K2SXYLDJFHEJUSQPWOTDTSWTLIBXRX4' #Foursquare ID
    CLIENT_SECRET = 'FO50QPHK05HPVMOS3ZNASGMCSVFVWMP2IZIDZZMACXLQBZI2' #Foursquare Secret
    VERSION = '20180605' # Foursquare API version
    
    #url to fetch data from foursquare api
    url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
    
    # get all the data
    results = requests.get(url).json()
    venue_data=results["response"]['groups'][0]['items']
    venue_details=[]
    for row in venue_data:
        try:
            venue_id=row['venue']['id']
            venue_name=row['venue']['name']
            venue_category=row['venue']['categories'][0]['name']
            venue_details.append([venue_id,venue_name,venue_category])
        except KeyError:
            pass
        
    column_names=['ID','Name','Category']
    df = pd.DataFrame(venue_details,columns=column_names)
    print("done")
    return df

# %% [markdown]
# Now we get venue details like name, rating , tips, likes etc.

# %%
def get_venue_details(venue_id):
        
    CLIENT_ID = 'ABKHZGTMF5MNAOGB0K2SXYLDJFHEJUSQPWOTDTSWTLIBXRX4' #Foursquare ID
    CLIENT_SECRET = 'FO50QPHK05HPVMOS3ZNASGMCSVFVWMP2IZIDZZMACXLQBZI2' #Foursquare Secret
    VERSION = '20180605' # Foursquare API version
    
    #url to fetch data from foursquare api
    url = 'https://api.foursquare.com/v2/venues/{}?&client_id={}&client_secret={}&v={}'.format(
            venue_id,
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION)
    
    # get all the data
    results = requests.get(url).json()
    venue_data=results['response']['venue']
    venue_details=[]
    try:
        venue_id=venue_data['id']
        venue_name=venue_data['name']
        venue_likes=venue_data['likes']['count']
        venue_rating=venue_data['rating']
        venue_tips=venue_data['tips']['count']
        venue_details.append([venue_id,venue_name,venue_likes,venue_rating,venue_tips])
    except KeyError:
        pass
        
    column_names=['ID','Name','Likes','Rating','Tips']
    df = pd.DataFrame(venue_details,columns=column_names)
    return df

# %% [markdown]
# Now we get NYC details such as boroughs, neighborhoods and locations (latitude & longitude).

# %%
def get_new_york_data():
    url='https://cocl.us/new_york_dataset'
    resp=requests.get(url).json()
    # all data is present in features label
    features=resp['features']
    
    # define the dataframe columns
    column_names = ['Borough', 'Neighborhood', 'Latitude', 'Longitude'] 
    # instantiate the dataframe
    new_york_data = pd.DataFrame(columns=column_names)
    
    for data in features:
        borough = data['properties']['borough'] 
        neighborhood_name = data['properties']['name']
        
        neighborhood_latlon = data['geometry']['coordinates']
        neighborhood_lat = neighborhood_latlon[1]
        neighborhood_lon = neighborhood_latlon[0]
    
        new_york_data = new_york_data.append({'Borough': borough,
                                          'Neighborhood': neighborhood_name,
                                          'Latitude': neighborhood_lat,
                                          'Longitude': neighborhood_lon}, ignore_index=True)
    
    return new_york_data

# %% [markdown]
# We call the object to get NYC data.

# %%
# get new york data
new_york_data=get_new_york_data()
new_york_data.head()
# Out:
#   Borough Neighborhood   Latitude  Longitude
# 0   Bronx    Wakefield  40.894705 -73.847201
# 1   Bronx   Co-op City  40.874294 -73.829939
# 2   Bronx  Eastchester  40.887556 -73.827806
# 3   Bronx    Fieldston  40.895437 -73.905643
# 4   Bronx    Riverdale  40.890834 -73.912585

# %%
new_york_data.shape
# Out:
# (306, 4)

# %% [markdown]
# There are total of 306 different Neighborhoods in NYC

# %% [markdown]
# Now we collect Colombian restaurants for each Neighborhood

# %%
# prepare neighborhood list that contains Colombian restaurants
column_names=['Borough', 'Neighborhood', 'ID','Name']
colombian_rest_ny=pd.DataFrame(columns=column_names)
count=1
for row in new_york_data.values.tolist():
    Borough, Neighborhood, Latitude, Longitude=row
    venues = get_venues(Latitude,Longitude)
    colombian_restaurants=venues[venues['Category']=='Colombian Restaurant']   
    print('(',count,'/',len(new_york_data),')','Colombian Restaurants in '+Neighborhood+', '+Borough+':'+str(len(colombian_restaurants)))
    for restaurant_detail in colombian_restaurants.values.tolist():
        id, name , category=restaurant_detail
        colombian_rest_ny = colombian_rest_ny.append({'Borough': Borough,
                                                'Neighborhood': Neighborhood, 
                                                'ID': id,
                                                'Name' : name
                                               }, ignore_index=True)
    count+=1
# Out:
# done
# ( 1 / 306 ) Colombian Restaurants in Wakefield, Bronx:0
# done
# ( 2 / 306 ) Colombian Restaurants in Co-op City, Bronx:0
# done
# ( 3 / 306 ) Colombian Restaurants in Eastchester, Bronx:0
# done
# ( 4 / 306 ) Colombian Restaurants in Fieldston, Bronx:0
# done
# ( 5 / 306 ) Colombian Restaurants in Riverdale, Bronx:0
# done
# ( 6 / 306 ) Colombian Restaurants in Kingsbridge, Bronx:0
# done
# ( 7 / 306 ) Colombian Restaurants in Marble Hill, Manhattan:0
# done
# ( 8 / 306 ) Colombian Restaurants in Woodlawn, Bronx:0
# done
# ( 9 / 306 ) Colombian Restaurants in Norwood, Bronx:0
# done
# ( 10 / 306 ) Colombian Restaurants in Williamsbridge, Bronx:0
# done
# ( 11 / 306 ) Colombian Restaurants in Baychester, Bronx:0
# done
# ( 12 / 306 ) Colombian Restaurants in Pelham Parkway, Bronx:0
# done
# ( 13 / 306 ) Colombian Restaurants in City Island, Bronx:0
# done
# ( 14 / 306 ) Colombian Restaurants in Bedford Park, Bronx:0
# done
# ( 15 / 306 ) Colombian Restaurants in University Heights, Bronx:0
# done
# ( 16 / 306 ) Colombian Restaurants in Morris Heights, Bronx:0
# done
# ( 17 / 306 ) Colombian Restaurants in Fordham, Bronx:0
# done
# ( 18 / 306 ) Colombian Restaurants in East Tremont, Bronx:0
# done
# ( 19 / 306 ) Colombian Restaurants in West Farms, Bronx:0
# done
# ( 20 / 306 ) Colombian Restaurants in High  Bridge, Bronx:0
# done
# ( 21 / 306 ) Colombian Restaurants in Melrose, Bronx:0
# done
# ( 22 / 306 ) Colombian Restaurants in Mott Haven, Bronx:0
# done
# ( 23 / 306 ) Colombian Restaurants in Port Morris, Bronx:0
# done
# ( 24 / 306 ) Colombian Restaurants in Longwood, Bronx:0
# done
# ( 25 / 306 ) Colombian Restaurants in Hunts Point, Bronx:0
# done
# ( 26 / 306 ) Colombian Restaurants in Morrisania, Bronx:0
# done
# ( 27 / 306 ) Colombian Restaurants in Soundview, Bronx:0
# done
# ( 28 / 306 ) Colombian Restaurants in Clason Point, Bronx:0
# done
# ( 29 / 306 ) Colombian Restaurants in Throgs Neck, Bronx:0
# done
# ( 30 / 306 ) Colombian Restaurants in Country Club, Bronx:0
# done
# ( 31 / 306 ) Colombian Restaurants in Parkchester, Bronx:0
# done
# ( 32 / 306 ) Colombian Restaurants in Westchester Square, Bronx:0
# done
# ( 33 / 306 ) Colombian Restaurants in Van Nest, Bronx:0
# done
# ( 34 / 306 ) Colombian Restaurants in Morris Park, Bronx:0
# done
# ( 35 / 306 ) Colombian Restaurants in Belmont, Bronx:0
# done
# ( 36 / 306 ) Colombian Restaurants in Spuyten Duyvil, Bronx:0
# done
# ( 37 / 306 ) Colombian Restaurants in North Riverdale, Bronx:0
# done
# ( 38 / 306 ) Colombian Restaurants in Pelham Bay, Bronx:0
# done
# ( 39 / 306 ) Colombian Restaurants in Schuylerville, Bronx:0
# done
# ( 40 / 306 ) Colombian Restaurants in Edgewater Park, Bronx:0
# done
# ( 41 / 306 ) Colombian Restaurants in Castle Hill, Bronx:0
# done
# ( 42 / 306 ) Colombian Restaurants in Olinville, Bronx:0
# done
# ( 43 / 306 ) Colombian Restaurants in Pelham Gardens, Bronx:0
# done
# ( 44 / 306 ) Colombian Restaurants in Concourse, Bronx:0
# done
# ( 45 / 306 ) Colombian Restaurants in Unionport, Bronx:0
# done
# ( 46 / 306 ) Colombian Restaurants in Edenwald, Bronx:0
# done
# ( 47 / 306 ) Colombian Restaurants in Bay Ridge, Brooklyn:0
# done
# ( 48 / 306 ) Colombian Restaurants in Bensonhurst, Brooklyn:0
# done
# ( 49 / 306 ) Colombian Restaurants in Sunset Park, Brooklyn:0
# done
# ( 50 / 306 ) Colombian Restaurants in Greenpoint, Brooklyn:0
# done
# ( 51 / 306 ) Colombian Restaurants in Gravesend, Brooklyn:0
# done
# ( 52 / 306 ) Colombian Restaurants in Brighton Beach, Brooklyn:0
# done
# ( 53 / 306 ) Colombian Restaurants in Sheepshead Bay, Brooklyn:0
# done
# ( 54 / 306 ) Colombian Restaurants in Manhattan Terrace, Brooklyn:0
# done
# ( 55 / 306 ) Colombian Restaurants in Flatbush, Brooklyn:0
# done
# ( 56 / 306 ) Colombian Restaurants in Crown Heights, Brooklyn:0
# done
# ( 57 / 306 ) Colombian Restaurants in East Flatbush, Brooklyn:0
# done
# ( 58 / 306 ) Colombian Restaurants in Kensington, Brooklyn:0
# done
# ( 59 / 306 ) Colombian Restaurants in Windsor Terrace, Brooklyn:0
# done
# ( 60 / 306 ) Colombian Restaurants in Prospect Heights, Brooklyn:0
# done
# ( 61 / 306 ) Colombian Restaurants in Brownsville, Brooklyn:0
# done
# ( 62 / 306 ) Colombian Restaurants in Williamsburg, Brooklyn:0
# done
# ( 63 / 306 ) Colombian Restaurants in Bushwick, Brooklyn:0
# done
# ( 64 / 306 ) Colombian Restaurants in Bedford Stuyvesant, Brooklyn:0
# done
# ( 65 / 306 ) Colombian Restaurants in Brooklyn Heights, Brooklyn:0
# done
# ( 66 / 306 ) Colombian Restaurants in Cobble Hill, Brooklyn:0
# done
# ( 67 / 306 ) Colombian Restaurants in Carroll Gardens, Brooklyn:0
# done
# ( 68 / 306 ) Colombian Restaurants in Red Hook, Brooklyn:0
# done
# ( 69 / 306 ) Colombian Restaurants in Gowanus, Brooklyn:1
# done
# ( 70 / 306 ) Colombian Restaurants in Fort Greene, Brooklyn:0
# done
# ( 71 / 306 ) Colombian Restaurants in Park Slope, Brooklyn:1
# done
# ( 72 / 306 ) Colombian Restaurants in Cypress Hills, Brooklyn:0
# done
# ( 73 / 306 ) Colombian Restaurants in East New York, Brooklyn:0
# done
# ( 74 / 306 ) Colombian Restaurants in Starrett City, Brooklyn:0
# done
# ( 75 / 306 ) Colombian Restaurants in Canarsie, Brooklyn:0
# done
# ( 76 / 306 ) Colombian Restaurants in Flatlands, Brooklyn:0
# done
# ( 77 / 306 ) Colombian Restaurants in Mill Island, Brooklyn:0
# done
# ( 78 / 306 ) Colombian Restaurants in Manhattan Beach, Brooklyn:0
# done
# ( 79 / 306 ) Colombian Restaurants in Coney Island, Brooklyn:0
# done
# ( 80 / 306 ) Colombian Restaurants in Bath Beach, Brooklyn:0
# done
# ( 81 / 306 ) Colombian Restaurants in Borough Park, Brooklyn:0
# done
# ( 82 / 306 ) Colombian Restaurants in Dyker Heights, Brooklyn:0
# done
# ( 83 / 306 ) Colombian Restaurants in Gerritsen Beach, Brooklyn:0
# done
# ( 84 / 306 ) Colombian Restaurants in Marine Park, Brooklyn:0
# done
# ( 85 / 306 ) Colombian Restaurants in Clinton Hill, Brooklyn:0
# done
# ( 86 / 306 ) Colombian Restaurants in Sea Gate, Brooklyn:0
# done
# ( 87 / 306 ) Colombian Restaurants in Downtown, Brooklyn:0
# done
# ( 88 / 306 ) Colombian Restaurants in Boerum Hill, Brooklyn:1
# done
# ( 89 / 306 ) Colombian Restaurants in Prospect Lefferts Gardens, Brooklyn:0
# done
# ( 90 / 306 ) Colombian Restaurants in Ocean Hill, Brooklyn:0
# done
# ( 91 / 306 ) Colombian Restaurants in City Line, Brooklyn:0
# done
# ( 92 / 306 ) Colombian Restaurants in Bergen Beach, Brooklyn:0
# done
# ( 93 / 306 ) Colombian Restaurants in Midwood, Brooklyn:0
# done
# ( 94 / 306 ) Colombian Restaurants in Prospect Park South, Brooklyn:0
# done
# ( 95 / 306 ) Colombian Restaurants in Georgetown, Brooklyn:0
# done
# ( 96 / 306 ) Colombian Restaurants in East Williamsburg, Brooklyn:0
# done
# ( 97 / 306 ) Colombian Restaurants in North Side, Brooklyn:0
# done
# ( 98 / 306 ) Colombian Restaurants in South Side, Brooklyn:0
# done
# ( 99 / 306 ) Colombian Restaurants in Ocean Parkway, Brooklyn:0
# done
# ( 100 / 306 ) Colombian Restaurants in Fort Hamilton, Brooklyn:0
# done
# ( 101 / 306 ) Colombian Restaurants in Chinatown, Manhattan:0
# done
# ( 102 / 306 ) Colombian Restaurants in Washington Heights, Manhattan:0
# done
# ( 103 / 306 ) Colombian Restaurants in Inwood, Manhattan:0
# done
# ( 104 / 306 ) Colombian Restaurants in Hamilton Heights, Manhattan:0
# done
# ( 105 / 306 ) Colombian Restaurants in Manhattanville, Manhattan:0
# done
# ( 106 / 306 ) Colombian Restaurants in Central Harlem, Manhattan:0
# done
# ( 107 / 306 ) Colombian Restaurants in East Harlem, Manhattan:0
# done
# ( 108 / 306 ) Colombian Restaurants in Upper East Side, Manhattan:0
# done
# ( 109 / 306 ) Colombian Restaurants in Yorkville, Manhattan:0
# done
# ( 110 / 306 ) Colombian Restaurants in Lenox Hill, Manhattan:0
# done
# ( 111 / 306 ) Colombian Restaurants in Roosevelt Island, Manhattan:0
# done
# ( 112 / 306 ) Colombian Restaurants in Upper West Side, Manhattan:0
# done
# ( 113 / 306 ) Colombian Restaurants in Lincoln Square, Manhattan:0
# done
# ( 114 / 306 ) Colombian Restaurants in Clinton, Manhattan:0
# done
# ( 115 / 306 ) Colombian Restaurants in Midtown, Manhattan:0
# done
# ( 116 / 306 ) Colombian Restaurants in Murray Hill, Manhattan:0
# done
# ( 117 / 306 ) Colombian Restaurants in Chelsea, Manhattan:0
# done
# ( 118 / 306 ) Colombian Restaurants in Greenwich Village, Manhattan:0
# done
# ( 119 / 306 ) Colombian Restaurants in East Village, Manhattan:0
# done
# ( 120 / 306 ) Colombian Restaurants in Lower East Side, Manhattan:0
# done
# ( 121 / 306 ) Colombian Restaurants in Tribeca, Manhattan:0
# done
# ( 122 / 306 ) Colombian Restaurants in Little Italy, Manhattan:0
# done
# ( 123 / 306 ) Colombian Restaurants in Soho, Manhattan:0
# done
# ( 124 / 306 ) Colombian Restaurants in West Village, Manhattan:0
# done
# ( 125 / 306 ) Colombian Restaurants in Manhattan Valley, Manhattan:0
# done
# ( 126 / 306 ) Colombian Restaurants in Morningside Heights, Manhattan:0
# done
# ( 127 / 306 ) Colombian Restaurants in Gramercy, Manhattan:0
# done
# ( 128 / 306 ) Colombian Restaurants in Battery Park City, Manhattan:0
# done
# ( 129 / 306 ) Colombian Restaurants in Financial District, Manhattan:0
# done
# ( 130 / 306 ) Colombian Restaurants in Astoria, Queens:0
# done
# ( 131 / 306 ) Colombian Restaurants in Woodside, Queens:0
# done
# ( 132 / 306 ) Colombian Restaurants in Jackson Heights, Queens:0
# done
# ( 133 / 306 ) Colombian Restaurants in Elmhurst, Queens:0
# done
# ( 134 / 306 ) Colombian Restaurants in Howard Beach, Queens:0
# done
# ( 135 / 306 ) Colombian Restaurants in Corona, Queens:0
# done
# ( 136 / 306 ) Colombian Restaurants in Forest Hills, Queens:0
# done
# ( 137 / 306 ) Colombian Restaurants in Kew Gardens, Queens:0
# done
# ( 138 / 306 ) Colombian Restaurants in Richmond Hill, Queens:0
# done
# ( 139 / 306 ) Colombian Restaurants in Flushing, Queens:0
# done
# ( 140 / 306 ) Colombian Restaurants in Long Island City, Queens:0
# done
# ( 141 / 306 ) Colombian Restaurants in Sunnyside, Queens:0
# done
# ( 142 / 306 ) Colombian Restaurants in East Elmhurst, Queens:0
# done
# ( 143 / 306 ) Colombian Restaurants in Maspeth, Queens:0
# done
# ( 144 / 306 ) Colombian Restaurants in Ridgewood, Queens:0
# done
# ( 145 / 306 ) Colombian Restaurants in Glendale, Queens:0
# done
# ( 146 / 306 ) Colombian Restaurants in Rego Park, Queens:0
# done
# ( 147 / 306 ) Colombian Restaurants in Woodhaven, Queens:0
# done
# ( 148 / 306 ) Colombian Restaurants in Ozone Park, Queens:0
# done
# ( 149 / 306 ) Colombian Restaurants in South Ozone Park, Queens:0
# done
# ( 150 / 306 ) Colombian Restaurants in College Point, Queens:0
# done
# ( 151 / 306 ) Colombian Restaurants in Whitestone, Queens:0
# done
# ( 152 / 306 ) Colombian Restaurants in Bayside, Queens:0
# done
# ( 153 / 306 ) Colombian Restaurants in Auburndale, Queens:0
# done
# ( 154 / 306 ) Colombian Restaurants in Little Neck, Queens:0
# done
# ( 155 / 306 ) Colombian Restaurants in Douglaston, Queens:0
# done
# ( 156 / 306 ) Colombian Restaurants in Glen Oaks, Queens:0
# done
# ( 157 / 306 ) Colombian Restaurants in Bellerose, Queens:0
# done
# ( 158 / 306 ) Colombian Restaurants in Kew Gardens Hills, Queens:0
# done
# ( 159 / 306 ) Colombian Restaurants in Fresh Meadows, Queens:0
# done
# ( 160 / 306 ) Colombian Restaurants in Briarwood, Queens:1
# done
# ( 161 / 306 ) Colombian Restaurants in Jamaica Center, Queens:1
# done
# ( 162 / 306 ) Colombian Restaurants in Oakland Gardens, Queens:0
# done
# ( 163 / 306 ) Colombian Restaurants in Queens Village, Queens:0
# done
# ( 164 / 306 ) Colombian Restaurants in Hollis, Queens:0
# done
# ( 165 / 306 ) Colombian Restaurants in South Jamaica, Queens:1
# done
# ( 166 / 306 ) Colombian Restaurants in St. Albans, Queens:0
# done
# ( 167 / 306 ) Colombian Restaurants in Rochdale, Queens:0
# done
# ( 168 / 306 ) Colombian Restaurants in Springfield Gardens, Queens:0
# done
# ( 169 / 306 ) Colombian Restaurants in Cambria Heights, Queens:0
# done
# ( 170 / 306 ) Colombian Restaurants in Rosedale, Queens:0
# done
# ( 171 / 306 ) Colombian Restaurants in Far Rockaway, Queens:0
# done
# ( 172 / 306 ) Colombian Restaurants in Broad Channel, Queens:0
# done
# ( 173 / 306 ) Colombian Restaurants in Breezy Point, Queens:0
# done
# ( 174 / 306 ) Colombian Restaurants in Steinway, Queens:0
# done
# ( 175 / 306 ) Colombian Restaurants in Beechhurst, Queens:0
# done
# ( 176 / 306 ) Colombian Restaurants in Bay Terrace, Queens:0
# done
# ( 177 / 306 ) Colombian Restaurants in Edgemere, Queens:0
# done
# ( 178 / 306 ) Colombian Restaurants in Arverne, Queens:0
# done
# ( 179 / 306 ) Colombian Restaurants in Rockaway Beach, Queens:0
# done
# ( 180 / 306 ) Colombian Restaurants in Neponsit, Queens:0
# done
# ( 181 / 306 ) Colombian Restaurants in Murray Hill, Queens:0
# done
# ( 182 / 306 ) Colombian Restaurants in Floral Park, Queens:0
# done
# ( 183 / 306 ) Colombian Restaurants in Holliswood, Queens:0
# done
# ( 184 / 306 ) Colombian Restaurants in Jamaica Estates, Queens:1
# done
# ( 185 / 306 ) Colombian Restaurants in Queensboro Hill, Queens:0
# done
# ( 186 / 306 ) Colombian Restaurants in Hillcrest, Queens:1
# done
# ( 187 / 306 ) Colombian Restaurants in Ravenswood, Queens:0
# done
# ( 188 / 306 ) Colombian Restaurants in Lindenwood, Queens:0
# done
# ( 189 / 306 ) Colombian Restaurants in Laurelton, Queens:0
# done
# ( 190 / 306 ) Colombian Restaurants in Lefrak City, Queens:0
# done
# ( 191 / 306 ) Colombian Restaurants in Belle Harbor, Queens:0
# done
# ( 192 / 306 ) Colombian Restaurants in Rockaway Park, Queens:0
# done
# ( 193 / 306 ) Colombian Restaurants in Somerville, Queens:0
# done
# ( 194 / 306 ) Colombian Restaurants in Brookville, Queens:0
# done
# ( 195 / 306 ) Colombian Restaurants in Bellaire, Queens:0
# done
# ( 196 / 306 ) Colombian Restaurants in North Corona, Queens:0
# done
# ( 197 / 306 ) Colombian Restaurants in Forest Hills Gardens, Queens:0
# done
# ( 198 / 306 ) Colombian Restaurants in St. George, Staten Island:0
# done
# ( 199 / 306 ) Colombian Restaurants in New Brighton, Staten Island:0
# done
# ( 200 / 306 ) Colombian Restaurants in Stapleton, Staten Island:0
# done
# ( 201 / 306 ) Colombian Restaurants in Rosebank, Staten Island:0
# done
# ( 202 / 306 ) Colombian Restaurants in West Brighton, Staten Island:0
# done
# ( 203 / 306 ) Colombian Restaurants in Grymes Hill, Staten Island:0
# done
# ( 204 / 306 ) Colombian Restaurants in Todt Hill, Staten Island:0
# done
# ( 205 / 306 ) Colombian Restaurants in South Beach, Staten Island:0
# done
# ( 206 / 306 ) Colombian Restaurants in Port Richmond, Staten Island:0
# done
# ( 207 / 306 ) Colombian Restaurants in Mariner's Harbor, Staten Island:0
# done
# ( 208 / 306 ) Colombian Restaurants in Port Ivory, Staten Island:0
# done
# ( 209 / 306 ) Colombian Restaurants in Castleton Corners, Staten Island:0
# done
# ( 210 / 306 ) Colombian Restaurants in New Springville, Staten Island:0
# done
# ( 211 / 306 ) Colombian Restaurants in Travis, Staten Island:0
# done
# ( 212 / 306 ) Colombian Restaurants in New Dorp, Staten Island:0
# done
# ( 213 / 306 ) Colombian Restaurants in Oakwood, Staten Island:0
# done
# ( 214 / 306 ) Colombian Restaurants in Great Kills, Staten Island:0
# done
# ( 215 / 306 ) Colombian Restaurants in Eltingville, Staten Island:0
# done
# ( 216 / 306 ) Colombian Restaurants in Annadale, Staten Island:0
# done
# ( 217 / 306 ) Colombian Restaurants in Woodrow, Staten Island:0
# done
# ( 218 / 306 ) Colombian Restaurants in Tottenville, Staten Island:0
# done
# ( 219 / 306 ) Colombian Restaurants in Tompkinsville, Staten Island:0
# done
# ( 220 / 306 ) Colombian Restaurants in Silver Lake, Staten Island:0
# done
# ( 221 / 306 ) Colombian Restaurants in Sunnyside, Staten Island:0
# done
# ( 222 / 306 ) Colombian Restaurants in Ditmas Park, Brooklyn:0
# done
# ( 223 / 306 ) Colombian Restaurants in Wingate, Brooklyn:0
# done
# ( 224 / 306 ) Colombian Restaurants in Rugby, Brooklyn:0
# done
# ( 225 / 306 ) Colombian Restaurants in Park Hill, Staten Island:0
# done
# ( 226 / 306 ) Colombian Restaurants in Westerleigh, Staten Island:0
# done
# ( 227 / 306 ) Colombian Restaurants in Graniteville, Staten Island:0
# done
# ( 228 / 306 ) Colombian Restaurants in Arlington, Staten Island:0
# done
# ( 229 / 306 ) Colombian Restaurants in Arrochar, Staten Island:0
# done
# ( 230 / 306 ) Colombian Restaurants in Grasmere, Staten Island:0
# done
# ( 231 / 306 ) Colombian Restaurants in Old Town, Staten Island:0
# done
# ( 232 / 306 ) Colombian Restaurants in Dongan Hills, Staten Island:0
# done
# ( 233 / 306 ) Colombian Restaurants in Midland Beach, Staten Island:0
# done
# ( 234 / 306 ) Colombian Restaurants in Grant City, Staten Island:0
# done
# ( 235 / 306 ) Colombian Restaurants in New Dorp Beach, Staten Island:0
# done
# ( 236 / 306 ) Colombian Restaurants in Bay Terrace, Staten Island:0
# done
# ( 237 / 306 ) Colombian Restaurants in Huguenot, Staten Island:0
# done
# ( 238 / 306 ) Colombian Restaurants in Pleasant Plains, Staten Island:0
# done
# ( 239 / 306 ) Colombian Restaurants in Butler Manor, Staten Island:0
# done
# ( 240 / 306 ) Colombian Restaurants in Charleston, Staten Island:0
# done
# ( 241 / 306 ) Colombian Restaurants in Rossville, Staten Island:0
# done
# ( 242 / 306 ) Colombian Restaurants in Arden Heights, Staten Island:0
# done
# ( 243 / 306 ) Colombian Restaurants in Greenridge, Staten Island:0
# done
# ( 244 / 306 ) Colombian Restaurants in Heartland Village, Staten Island:0
# done
# ( 245 / 306 ) Colombian Restaurants in Chelsea, Staten Island:0
# done
# ( 246 / 306 ) Colombian Restaurants in Bloomfield, Staten Island:0
# done
# ( 247 / 306 ) Colombian Restaurants in Bulls Head, Staten Island:0
# done
# ( 248 / 306 ) Colombian Restaurants in Carnegie Hill, Manhattan:0
# done
# ( 249 / 306 ) Colombian Restaurants in Noho, Manhattan:0
# done
# ( 250 / 306 ) Colombian Restaurants in Civic Center, Manhattan:0
# done
# ( 251 / 306 ) Colombian Restaurants in Midtown South, Manhattan:0
# done
# ( 252 / 306 ) Colombian Restaurants in Richmond Town, Staten Island:0
# done
# ( 253 / 306 ) Colombian Restaurants in Shore Acres, Staten Island:0
# done
# ( 254 / 306 ) Colombian Restaurants in Clifton, Staten Island:0
# done
# ( 255 / 306 ) Colombian Restaurants in Concord, Staten Island:0
# done
# ( 256 / 306 ) Colombian Restaurants in Emerson Hill, Staten Island:0
# done
# ( 257 / 306 ) Colombian Restaurants in Randall Manor, Staten Island:0
# done
# ( 258 / 306 ) Colombian Restaurants in Howland Hook, Staten Island:0
# done
# ( 259 / 306 ) Colombian Restaurants in Elm Park, Staten Island:0
# done
# ( 260 / 306 ) Colombian Restaurants in Remsen Village, Brooklyn:0
# done
# ( 261 / 306 ) Colombian Restaurants in New Lots, Brooklyn:0
# done
# ( 262 / 306 ) Colombian Restaurants in Paerdegat Basin, Brooklyn:0
# done
# ( 263 / 306 ) Colombian Restaurants in Mill Basin, Brooklyn:0
# done
# ( 264 / 306 ) Colombian Restaurants in Jamaica Hills, Queens:1
# done
# ( 265 / 306 ) Colombian Restaurants in Utopia, Queens:0
# done
# ( 266 / 306 ) Colombian Restaurants in Pomonok, Queens:0
# done
# ( 267 / 306 ) Colombian Restaurants in Astoria Heights, Queens:0
# done
# ( 268 / 306 ) Colombian Restaurants in Claremont Village, Bronx:0
# done
# ( 269 / 306 ) Colombian Restaurants in Concourse Village, Bronx:0
# done
# ( 270 / 306 ) Colombian Restaurants in Mount Eden, Bronx:0
# done
# ( 271 / 306 ) Colombian Restaurants in Mount Hope, Bronx:0
# done
# ( 272 / 306 ) Colombian Restaurants in Sutton Place, Manhattan:0
# done
# ( 273 / 306 ) Colombian Restaurants in Hunters Point, Queens:0
# done
# ( 274 / 306 ) Colombian Restaurants in Turtle Bay, Manhattan:0
# done
# ( 275 / 306 ) Colombian Restaurants in Tudor City, Manhattan:0
# done
# ( 276 / 306 ) Colombian Restaurants in Stuyvesant Town, Manhattan:0
# done
# ( 277 / 306 ) Colombian Restaurants in Flatiron, Manhattan:0
# done
# ( 278 / 306 ) Colombian Restaurants in Sunnyside Gardens, Queens:0
# done
# ( 279 / 306 ) Colombian Restaurants in Blissville, Queens:0
# done
# ( 280 / 306 ) Colombian Restaurants in Fulton Ferry, Brooklyn:0
# done
# ( 281 / 306 ) Colombian Restaurants in Vinegar Hill, Brooklyn:0
# done
# ( 282 / 306 ) Colombian Restaurants in Weeksville, Brooklyn:0
# done
# ( 283 / 306 ) Colombian Restaurants in Broadway Junction, Brooklyn:0
# done
# ( 284 / 306 ) Colombian Restaurants in Dumbo, Brooklyn:0
# done
# ( 285 / 306 ) Colombian Restaurants in Manor Heights, Staten Island:0
# done
# ( 286 / 306 ) Colombian Restaurants in Willowbrook, Staten Island:0
# done
# ( 287 / 306 ) Colombian Restaurants in Sandy Ground, Staten Island:0
# done
# ( 288 / 306 ) Colombian Restaurants in Egbertville, Staten Island:0
# done
# ( 289 / 306 ) Colombian Restaurants in Roxbury, Queens:0
# done
# ( 290 / 306 ) Colombian Restaurants in Homecrest, Brooklyn:0
# done
# ( 291 / 306 ) Colombian Restaurants in Middle Village, Queens:0
# done
# ( 292 / 306 ) Colombian Restaurants in Prince's Bay, Staten Island:0
# done
# ( 293 / 306 ) Colombian Restaurants in Lighthouse Hill, Staten Island:0
# done
# ( 294 / 306 ) Colombian Restaurants in Richmond Valley, Staten Island:0
# done
# ( 295 / 306 ) Colombian Restaurants in Malba, Queens:0
# done
# ( 296 / 306 ) Colombian Restaurants in Highland Park, Brooklyn:0
# done
# ( 297 / 306 ) Colombian Restaurants in Madison, Brooklyn:0
# done
# ( 298 / 306 ) Colombian Restaurants in Bronxdale, Bronx:0
# done
# ( 299 / 306 ) Colombian Restaurants in Allerton, Bronx:0
# done
# ( 300 / 306 ) Colombian Restaurants in Kingsbridge Heights, Bronx:0
# done
# ( 301 / 306 ) Colombian Restaurants in Erasmus, Brooklyn:0
# done
# ( 302 / 306 ) Colombian Restaurants in Hudson Yards, Manhattan:0
# done
# ( 303 / 306 ) Colombian Restaurants in Hammels, Queens:1
# done
# ( 304 / 306 ) Colombian Restaurants in Bayswater, Queens:0
# done
# ( 305 / 306 ) Colombian Restaurants in Queensbridge, Queens:0
# done
# ( 306 / 306 ) Colombian Restaurants in Fox Hills, Staten Island:0

# %% [markdown]
# Now we got all Colombian restaurants in NYC

# %%
colombian_rest_ny.shape
# Out:
# (10, 4)

# %% [markdown]
# We found 10 Colombian restaurants in NYC. Let's Vizualize it

# %%
ny_map = folium.Map(location=geo_location('New York'), zoom_start=11)
incidents = folium.map.FeatureGroup()

ny_neighborhood_stats=pd.merge(colombian_rest_ny,new_york_data, on='Neighborhood')
for lat, lng, in ny_neighborhood_stats[['Latitude','Longitude']].values:
    incidents.add_child(
        folium.CircleMarker(
            [lat, lng],
            radius=10, # define how big you want the circle markers to be
            color='yellow',
            fill=True,
            fill_color='blue',
            fill_opacity=0.6
        )
    )
    
# add pop-up text to each marker on the map
for lat, lng in ny_neighborhood_stats[['Latitude','Longitude']].values:
    folium.Marker([lat, lng]).add_to(ny_map)        
# add incidents to map
ny_map.add_child(incidents)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Conclusion
# There are clearly 2 clusters that seem to be relevant, Brooklyn & Queens. Further inspection on the size of these reveals that Queens is the borough where most Colombian people gather according to the data provided by FourSquare. Therefore, the new Colombian consulate should be located here.
